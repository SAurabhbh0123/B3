# %%
a=1
b=1
print(id(a))
# Out:
# 140736127484712

# %%
print(id(b))
# Out:
# 140736127484712

# %%
c=1
print(id(c))
# Out:
# 140736127484712

# %%
c=c+1
print(id(c))
# Out:
# 140736127484744

# %%
d=10
for i in range(0,10000):
    print(id(d))
# Out:
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# 140736127485000
# ...

# %%
listOfInt= [1,2,3,5,7,8.0]

# %%
listOfInt
# Out:
# [1, 2, 3, 5, 7, 8.0]

# %%
len(listOfInt)
# Out:
# 6

# %%
listOfInt[-1]
# Out:
# 8.0

# %%
listOfInt.append(10)

# %%
listOfInt
# Out:
# [1, 2, 3, 5, 7, 8.0, 10]

# %%
listOfInt.remove(8.0)

# %%
listOfInt
# Out:
# [1, 2, 3, 5, 7, 10]

# %%
a=[1,3]
b=[2,6]

# %%
c=[a,b]
c
# Out:
# [[1, 3], [2, 6]]

# %%
c[1][0]
# Out:
# 2

# %%
a*2
# Out:
# [1, 3, 1, 3]

# %%
a=(10 ,11)#tuple
a[0]
# Out:
# 10

# %%
print(a)
# Out:
# (10, 11)

# %%
seta={1,2,3} #sets
print(seta)
# Out:
# {1, 2, 3}

# %%
#dictionary or json

# %%
dicta={"name":"saurabh", "batch":"b1"}
#key:value
print(dicta)
# Out:
# {'name': 'saurabh', 'batch': 'b1'}

# %%
dicta["name"]
# Out:
# 'saurabh'
